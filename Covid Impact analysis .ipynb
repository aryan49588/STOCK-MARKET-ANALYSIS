# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mydata=pd.read_csv('raw_data.csv')
mydata
# Out:
#       iso_code     location        date  total_cases  total_deaths  \
# 0          AFG  Afghanistan  2019-12-31          0.0           0.0
# 1          AFG  Afghanistan  2020-01-01          0.0           0.0
# 2          AFG  Afghanistan  2020-01-02          0.0           0.0
# 3          AFG  Afghanistan  2020-01-03          0.0           0.0
# 4          AFG  Afghanistan  2020-01-04          0.0           0.0
# ...        ...          ...         ...          ...           ...
# 50413      ZWE     Zimbabwe  2020-10-15       8055.0         231.0
# 50414      ZWE     Zimbabwe  2020-10-16       8075.0         231.0
# 50415      ZWE     Zimbabwe  2020-10-17       8099.0         231.0
# 50416      ZWE     Zimbabwe  2020-10-18       8110.0         231.0
# 50417      ZWE     Zimbabwe  2020-10-19       8147.0         231.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# 0                  0.00    38928341        1803.987                    0.498
# ...

# %%
mydata.count()
# Out:
# iso_code                   50418
# location                   50418
# date                       50418
# total_cases                47324
# total_deaths               39228
# stringency_index           43292
# population                 50418
# gdp_per_capita             44706
# human_development_index    44216
# Unnamed: 9                 50418
# Unnamed: 10                50418
# Unnamed: 11                50418
# Unnamed: 12                50418
# Unnamed: 13                50418
# dtype: int64

# %%
mydata['date'] = pd.to_datetime(mydata['date'], format='%Y-%m-%d')

# %%
mydata
# Out:
#       iso_code     location       date  total_cases  total_deaths  \
# 0          AFG  Afghanistan 2019-12-31          0.0           0.0
# 1          AFG  Afghanistan 2020-01-01          0.0           0.0
# 2          AFG  Afghanistan 2020-01-02          0.0           0.0
# 3          AFG  Afghanistan 2020-01-03          0.0           0.0
# 4          AFG  Afghanistan 2020-01-04          0.0           0.0
# ...        ...          ...        ...          ...           ...
# 50413      ZWE     Zimbabwe 2020-10-15       8055.0         231.0
# 50414      ZWE     Zimbabwe 2020-10-16       8075.0         231.0
# 50415      ZWE     Zimbabwe 2020-10-17       8099.0         231.0
# 50416      ZWE     Zimbabwe 2020-10-18       8110.0         231.0
# 50417      ZWE     Zimbabwe 2020-10-19       8147.0         231.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# 0                  0.00    38928341        1803.987                    0.498
# ...

# %%
filtered_mydata=mydata.loc[(mydata['date'] >= '2020-09-01') 
                       & (mydata['date'] < '2020-09-02')]
filtered_mydata
# Out:
#       iso_code     location       date  total_cases  total_deaths  \
# 245        AFG  Afghanistan 2020-09-01      38196.0        1406.0
# 470        ALB      Albania 2020-09-01       9513.0         284.0
# 764        DZA      Algeria 2020-09-01      44494.0        1510.0
# 990        AND      Andorra 2020-09-01       1176.0          53.0
# 1202       AGO       Angola 2020-09-01       2624.0         107.0
# ...        ...          ...        ...          ...           ...
# 49454      VEN    Venezuela 2020-09-01      45868.0         381.0
# 49748      VNM      Vietnam 2020-09-01       1044.0          34.0
# 49941      YEM        Yemen 2020-09-01       1958.0         566.0
# 50156      ZMB       Zambia 2020-09-01      12097.0         288.0
# 50369      ZWE     Zimbabwe 2020-09-01       6497.0         202.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# 245               21.30    38928341        1803.987                    0.498
# ...

# %%
sorted_data=filtered_mydata.sort_values('total_cases',ascending=False)
sorted_data
# Out:
#       iso_code          location       date  total_cases  total_deaths  \
# 48366      USA     United States 2020-09-01    6031013.0      183598.0
# 6816       BRA            Brazil 2020-09-01    3908272.0      121381.0
# 21673      IND             India 2020-09-01    3691166.0       65228.0
# 38297      RUS            Russia 2020-09-01     995319.0       17176.0
# 36454      PER              Peru 2020-09-01     652037.0       28944.0
# ...        ...               ...        ...          ...           ...
# 15806      FLK  Falkland Islands 2020-09-01         13.0           NaN
# 31527      MSR        Montserrat 2020-09-01         13.0           1.0
# 49235      VAT           Vatican 2020-09-01         12.0           NaN
# 1409       AIA          Anguilla 2020-09-01          3.0           NaN
# 20861      HKG         Hong Kong 2020-09-01          NaN           NaN
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# ...

# %%
print("Top ten countries with highest number of total cases as on 2020-09-01")
sorted_data.head(10)
# Out:
# Top ten countries with highest number of total cases as on 2020-09-01
#       iso_code       location       date  total_cases  total_deaths  \
# 48366      USA  United States 2020-09-01    6031013.0      183598.0
# 6816       BRA         Brazil 2020-09-01    3908272.0      121381.0
# 21673      IND          India 2020-09-01    3691166.0       65228.0
# 38297      RUS         Russia 2020-09-01     995319.0       17176.0
# 36454      PER           Peru 2020-09-01     652037.0       28944.0
# 30360      MEX         Mexico 2020-09-01     648171.0       64414.0
# 42225      ZAF   South Africa 2020-09-01     627041.0       14149.0
# 10315      COL       Colombia 2020-09-01     615168.0       19663.0
# 43010      ESP          Spain 2020-09-01     470973.0       29152.0
# 9792       CHL          Chile 2020-09-01     411726.0       11289.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# ...

# %%
sns.set(rc={'figure.figsize':(15,8)})
sns.barplot(x="location",y="total_cases",data=sorted_data.head(10),hue="location")
plt.show()

# %%
#For example we can analyse covid 19 impact for particular country ,say, Mexico

# %%
mexico=mydata[mydata['location']=='Mexico']
mexico
# Out:
#       iso_code location       date  total_cases  total_deaths  \
# 30115      MEX   Mexico 2019-12-31          NaN           NaN
# 30116      MEX   Mexico 2020-01-01          NaN           NaN
# 30117      MEX   Mexico 2020-01-02          NaN           NaN
# 30118      MEX   Mexico 2020-01-03          NaN           NaN
# 30119      MEX   Mexico 2020-01-04          NaN           NaN
# ...        ...      ...        ...          ...           ...
# 30404      MEX   Mexico 2020-10-15     845257.0       84898.0
# 30405      MEX   Mexico 2020-10-16     846727.0       85285.0
# 30406      MEX   Mexico 2020-10-17     847107.0       85704.0
# 30407      MEX   Mexico 2020-10-18     849907.0       86059.0
# 30408      MEX   Mexico 2020-10-19     851227.0       86167.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# 30115               NaN   128932753       17336.469                    0.774
# ...

# %%
mex_data=mexico.loc[(mexico['date']>='2020-10-01')
          & (mexico['date'] <='2020-10-30')]
mex_data
# Out:
#       iso_code location       date  total_cases  total_deaths  \
# 30390      MEX   Mexico 2020-10-01     789286.0       77646.0
# 30391      MEX   Mexico 2020-10-02     794241.0       78078.0
# 30392      MEX   Mexico 2020-10-03     798940.0       78492.0
# 30393      MEX   Mexico 2020-10-04     801206.0       78880.0
# 30394      MEX   Mexico 2020-10-05     802786.0       79088.0
# 30395      MEX   Mexico 2020-10-06     808033.0       79268.0
# 30396      MEX   Mexico 2020-10-07     813438.0       79714.0
# 30397      MEX   Mexico 2020-10-08     818613.0       80083.0
# 30398      MEX   Mexico 2020-10-09     823549.0       83096.0
# 30399      MEX   Mexico 2020-10-10     828558.0       83507.0
# 30400      MEX   Mexico 2020-10-11     830993.0       83642.0
# 30401      MEX   Mexico 2020-10-12     832743.0       83642.0
# 30402      MEX   Mexico 2020-10-13     838069.0       83945.0
# 30403      MEX   Mexico 2020-10-14     842617.0       84420.0
# ...

# %%
print("Rising cases in MEXICO...............")
sns.set(rc={'figure.figsize':(15,8)})
sns.lineplot(x='total_cases',y='date',data=mex_data,color='red')
plt.show()
# Out:
# Rising cases in MEXICO...............

# %%
#For example we can analyse covid 19 impact for particular country ,say, Sweden

# %%
sweden=mydata[mydata['location']=='Sweden']
sweden
# Out:
#       iso_code location       date  total_cases  total_deaths  \
# 44005      SWE   Sweden 2019-12-31          NaN           NaN
# 44006      SWE   Sweden 2020-01-01          NaN           NaN
# 44007      SWE   Sweden 2020-01-02          NaN           NaN
# 44008      SWE   Sweden 2020-01-03          NaN           NaN
# 44009      SWE   Sweden 2020-01-04          NaN           NaN
# ...        ...      ...        ...          ...           ...
# 44291      SWE   Sweden 2020-10-12     100081.0        5913.0
# 44292      SWE   Sweden 2020-10-13     100718.0        5914.0
# 44293      SWE   Sweden 2020-10-14     101634.0        5916.0
# 44294      SWE   Sweden 2020-10-15     102604.0        5917.0
# 44295      SWE   Sweden 2020-10-16     103200.0        5918.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# 44005               NaN    10099270       46949.283                    0.933
# ...

# %%
swe_data=sweden.loc[(sweden['date']>='2020-09-01')
          & (sweden['date'] <='2020-09-30')]
swe_data
# Out:
#       iso_code location       date  total_cases  total_deaths  \
# 44250      SWE   Sweden 2020-09-01      84394.0        5834.0
# 44251      SWE   Sweden 2020-09-02      84565.0        5836.0
# 44252      SWE   Sweden 2020-09-03      84778.0        5839.0
# 44253      SWE   Sweden 2020-09-04      85064.0        5841.0
# 44254      SWE   Sweden 2020-09-05      85326.0        5843.0
# 44255      SWE   Sweden 2020-09-06      85497.0        5843.0
# 44256      SWE   Sweden 2020-09-07      85564.0        5843.0
# 44257      SWE   Sweden 2020-09-08      85749.0        5846.0
# 44258      SWE   Sweden 2020-09-09      85985.0        5847.0
# 44259      SWE   Sweden 2020-09-10      86299.0        5848.0
# 44260      SWE   Sweden 2020-09-11      86555.0        5850.0
# 44261      SWE   Sweden 2020-09-12      86847.0        5852.0
# 44262      SWE   Sweden 2020-09-13      87053.0        5856.0
# 44263      SWE   Sweden 2020-09-14      87159.0        5857.0
# ...

# %%
print("Rise in total covid cases in Sweden from date 2020-09-01 to 2020-10-01")

sns.set(rc={'figure.figsize':(15,8)})
sns.barplot(x="total_cases",y="date",data=swe_data,hue='location')
plt.show()
# Out:
# Rise in total covid cases in Sweden from date 2020-09-01 to 2020-10-01

# %%
print("Rise in total covid cases in Sweden from date 2020-09-01 to 2020-10-01")

sns.lineplot(x="total_cases",y='date',data=swe_data,color='Green')
plt.show()
# Out:
# Rise in total covid cases in Sweden from date 2020-09-01 to 2020-10-01

# %%
sns.relplot(x="total_cases",y='date',data=swe_data)
plt.show()

# %%
mydata
# Out:
#       iso_code     location       date  total_cases  total_deaths  \
# 0          AFG  Afghanistan 2019-12-31          0.0           0.0
# 1          AFG  Afghanistan 2020-01-01          0.0           0.0
# 2          AFG  Afghanistan 2020-01-02          0.0           0.0
# 3          AFG  Afghanistan 2020-01-03          0.0           0.0
# 4          AFG  Afghanistan 2020-01-04          0.0           0.0
# ...        ...          ...        ...          ...           ...
# 50413      ZWE     Zimbabwe 2020-10-15       8055.0         231.0
# 50414      ZWE     Zimbabwe 2020-10-16       8075.0         231.0
# 50415      ZWE     Zimbabwe 2020-10-17       8099.0         231.0
# 50416      ZWE     Zimbabwe 2020-10-18       8110.0         231.0
# 50417      ZWE     Zimbabwe 2020-10-19       8147.0         231.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# 0                  0.00    38928341        1803.987                    0.498
# ...

# %%
mydata.sort_values('stringency_index')
# Out:
#       iso_code     location       date  total_cases  total_deaths  \
# 0          AFG  Afghanistan 2019-12-31          0.0           0.0
# 24356      JEY       Jersey 2020-08-09        345.0          31.0
# 24357      JEY       Jersey 2020-08-10        345.0          31.0
# 24358      JEY       Jersey 2020-08-11        347.0          31.0
# 24359      JEY       Jersey 2020-08-12        347.0          31.0
# ...        ...          ...        ...          ...           ...
# 50200      ZMB       Zambia 2020-10-15      15616.0         345.0
# 50201      ZMB       Zambia 2020-10-16      15659.0         346.0
# 50202      ZMB       Zambia 2020-10-17      15659.0         346.0
# 50203      ZMB       Zambia 2020-10-18      15789.0         346.0
# 50204      ZMB       Zambia 2020-10-19      15853.0         346.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# 0                   0.0    38928341        1803.987                    0.498
# ...

# %%
gdp=mydata.sort_values('gdp_per_capita')
gdp
# Out:
#       iso_code                  location       date  total_cases  \
# 9263       CAF  Central African Republic 2020-06-07       1570.0
# 9258       CAF  Central African Republic 2020-06-02       1069.0
# 9257       CAF  Central African Republic 2020-06-01       1011.0
# 9256       CAF  Central African Republic 2020-05-31        962.0
# 9255       CAF  Central African Republic 2020-05-30        874.0
# ...        ...                       ...        ...          ...
# 49279      VAT                   Vatican 2020-10-15         19.0
# 49280      VAT                   Vatican 2020-10-16         26.0
# 49281      VAT                   Vatican 2020-10-17         26.0
# 49282      VAT                   Vatican 2020-10-18         26.0
# 49283      VAT                   Vatican 2020-10-19         26.0
#
#        total_deaths  stringency_index  population  gdp_per_capita  \
# 9263            5.0             75.93     4829764          661.24
# ...

# %%
gdp=mydata.sort_values('human_development_index')
gdp
# Out:
#        iso_code location       date  total_cases  total_deaths  \
# 25305  OWID_KOS   Kosovo 2020-10-01      15620.0         625.0
# 25241  OWID_KOS   Kosovo 2020-07-29       7652.0         192.0
# 25242  OWID_KOS   Kosovo 2020-07-30       7846.0         196.0
# 25243  OWID_KOS   Kosovo 2020-07-31       8104.0         212.0
# 25244  OWID_KOS   Kosovo 2020-08-01       8330.0         227.0
# ...         ...      ...        ...          ...           ...
# 49279       VAT  Vatican 2020-10-15         19.0           NaN
# 49280       VAT  Vatican 2020-10-16         26.0           NaN
# 49281       VAT  Vatican 2020-10-17         26.0           NaN
# 49282       VAT  Vatican 2020-10-18         26.0           NaN
# 49283       VAT  Vatican 2020-10-19         26.0           NaN
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# 25305             58.33     1932774        9795.834                      0.0
# ...

# %%
filt_gdp=gdp[(gdp['human_development_index']>=0.7) & (gdp['human_development_index']<=0.9)]#filtered data
filt_gdp
# Out:
#       iso_code  location       date  total_cases  total_deaths  \
# 30569      MDA   Moldova 2020-08-17      30183.0         896.0
# 30573      MDA   Moldova 2020-08-21      31937.0         921.0
# 30568      MDA   Moldova 2020-08-16      29905.0         895.0
# 30570      MDA   Moldova 2020-08-18      30377.0         908.0
# 30571      MDA   Moldova 2020-08-19      30789.0         908.0
# ...        ...       ...        ...          ...           ...
# 41726      SVN  Slovenia 2020-08-10       2249.0         120.0
# 41727      SVN  Slovenia 2020-08-11       2255.0         120.0
# 41728      SVN  Slovenia 2020-08-12       2272.0         120.0
# 41725      SVN  Slovenia 2020-08-09       2247.0         120.0
# 41719      SVN  Slovenia 2020-08-03       2180.0         117.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# 30569             57.41     4033963        5189.972                    0.700
# ...

# %%
filt_gdp['location']
# Out:
# 30569     Moldova
# 30573     Moldova
# 30568     Moldova
# 30570     Moldova
# 30571     Moldova
#            ...
# 41726    Slovenia
# 41727    Slovenia
# 41728    Slovenia
# 41725    Slovenia
# 41719    Slovenia
# Name: location, Length: 20696, dtype: object

# %%
filt_gdp['location'].drop_duplicates().count()
# Out:
# 83

# %%
#there are 83 Countries with high HDI (high HDI refers to HDI in the range of 0.7 to 0.9.)

# %%
filt_gdp['location'].iloc[300]
# Out:
# 'Paraguay'

# %%
para=filt_gdp[filt_gdp['location']=='Paraguay']
para
# Out:
#       iso_code  location       date  total_cases  total_deaths  \
# 36113      PRY  Paraguay 2020-05-18        786.0          11.0
# 36114      PRY  Paraguay 2020-05-19        788.0          11.0
# 36115      PRY  Paraguay 2020-05-20        829.0          11.0
# 36116      PRY  Paraguay 2020-05-21        833.0          11.0
# 36117      PRY  Paraguay 2020-05-22        836.0          11.0
# ...        ...       ...        ...          ...           ...
# 36162      PRY  Paraguay 2020-07-06       2427.0          20.0
# 36045      PRY  Paraguay 2020-03-11          5.0           NaN
# 36220      PRY  Paraguay 2020-09-02      18338.0         348.0
# 36164      PRY  Paraguay 2020-07-08       2502.0          20.0
# 36143      PRY  Paraguay 2020-06-17       1303.0          13.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# 36113             94.44     7132530         8827.01                    0.702
# ...

# %%
sns.set(rc={'figure.figsize':(15,9)})
sns.lineplot(x="total_deaths",y="date",data=para,color='Brown')
plt.show()

# %%
#Number of deaths exploded in the months of August, September and october in 202 in Paraguay.
